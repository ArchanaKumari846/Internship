# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\archana\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\archana\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\users\archana\anaconda3\lib\site-packages (from selenium) (0.21.0)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\users\archana\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Requirement already satisfied: async-generator>=1.9 in c:\users\archana\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sniffio in c:\users\archana\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: outcome in c:\users\archana\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\archana\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: idna in c:\users\archana\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\archana\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\archana\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: pycparser in c:\users\archana\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\archana\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\archana\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\archana\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\archana\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in c:\users\archana\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: six>=1.5.2 in c:\users\archana\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\archana\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By

import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Q1. Answer:- A python program to scrape data for “Data Analyst” Job position in “Bangalore” location and have to scrape first 10 jobs data of the job-title, job-location, company_name, experience_required

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
url='https://www.naukri.com/'
driver.get(url)

# %%
driver.maximize_window()

# %%
search_jobs=driver.find_element(By.CLASS_NAME,'suggestor-input').send_keys("Data Analyst")

# %%
search_location= driver.find_element("xpath",('/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div/input')).send_keys('Bangalore')

# %%
search_button= driver.find_element("xpath",'/html/body/div[1]/div[2]/div[3]/div/div/div[6]').click()

# %%
title_tags=driver.find_elements("xpath",'//a[@class="title fw500 ellipsis"]')
job_title=[]
for i in title_tags:
    job_title.append(i.text)

# %%
loc_tags=driver.find_elements("xpath",'//li[@class="fleft grey-text br2 placeHolderLi location"]')
job_loc=[]
for i in loc_tags:
    job_loc.append(i.text)

# %%
comp_tags=driver.find_elements("xpath",'//a[@class="subTitle ellipsis fleft"]')
comp_title=[]
for i in comp_tags:
    comp_title.append(i.text)

# %%
exp_tags=driver.find_elements("xpath",'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
job_exp=[]
for i in exp_tags:
    job_exp.append(i.text)

# %%
Data_Analyst_1=pd.DataFrame({'Job Title':job_title[:10],'Job Location':job_loc[:10],'Company Name':comp_title[:10],'Experience':job_exp[:10]})
Data_Analyst_1[0:10]
# Out:
#                                            Job Title  \
# 0                           Sr.Business Data Analyst
# 1                                    Sr Data Analyst
# 2                       Senior Data Analysis Analyst
# 3  Job opportunity For Data Analyst at Trellance ...
# 4                                       Data Analyst
# 5                                Senior Data Analyst
# 6            Master Data Management Business Analyst
# 7                                       Data Analyst
# 8                             Associate Data Analyst
# 9                             Associate Data Analyst
#
#                                         Job Location  \
# 0  Bangalore/Bengaluru, karnataka\n(WFH during Co...
# 1                                Bangalore/Bengaluru
# 2                 Bangalore/Bengaluru, Pune, Chennai
# 3                     Bangalore/Bengaluru, Ahmedabad
# 4                                Bangalore/Bengaluru
# 5               Bangalore/Bengaluru(Old Madras Road)
# 6                                Bangalore/Bengaluru
# 7  Bangalore/Bengaluru, Noida, Hyderabad/Secunder...
# 8                                Bangalore/Bengaluru
# 9                                Bangalore/Bengaluru
#
#                  Company Name Experience
# 0                   Collabera   6-11 Yrs
# 1             Thomson Reuters    5-8 Yrs
# 2                       Capco   7-12 Yrs
# 3  CURise Analytics Pvt. Ltd.    0-2 Yrs
# 4             Thomson Reuters    2-3 Yrs
# 5                    KrazyBee    3-6 Yrs
# 6                   Accenture    6-8 Yrs
# 7                       Wipro    4-9 Yrs
# 8                       Optum    2-7 Yrs
# 9                       Optum    1-4 Yrs

# %% [markdown]
# # Q2. Answer:- A python program to scrape data for “Data Analyst” Job position in “Bangalore” location and have to scrape first 10 jobs data of the job-title, job-location, company_name

# %%
driver2=webdriver.Chrome('chromedriver.exe')
driver2.get('https://www.naukri.com/')

# %%
driver2.maximize_window()

# %%
search_jobs2=driver2.find_element(By.CLASS_NAME,'suggestor-input').send_keys("Data Analyst")

# %%
search_location2= driver2.find_element("xpath",('/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div/input')).send_keys('Bangalore')

# %%
search_button2= driver2.find_element("xpath",'/html/body/div[1]/div[2]/div[3]/div/div/div[6]').click()

# %%
title_tags2=driver2.find_elements("xpath",'//a[@class="title fw500 ellipsis"]')
job_title2=[]
for i in title_tags2:
    job_title2.append(i.text)

# %%
loc_tags2=driver2.find_elements("xpath",'//li[@class="fleft grey-text br2 placeHolderLi location"]')
job_loc2=[]
for i in loc_tags2:
    job_loc2.append(i.text)

# %%
comp_tags2=driver2.find_elements("xpath",'//a[@class="subTitle ellipsis fleft"]')
comp_title2=[]
for i in comp_tags2:
    comp_title2.append(i.text)

# %%
Data_Analyst_2=pd.DataFrame({'Job Title':job_title2,'Job Location':job_loc2,'Company Name':comp_title2})
Data_Analyst_2[0:10]
# Out:
#                                            Job Title  \
# 0                           Sr.Business Data Analyst
# 1                                    Sr Data Analyst
# 2                       Senior Data Analysis Analyst
# 3  Job opportunity For Data Analyst at Trellance ...
# 4                                       Data Analyst
# 5                             Associate Data Analyst
# 6                             Associate Data Analyst
# 7                                       Data Analyst
# 8                                Senior Data Analyst
# 9                             Financial Data Analyst
#
#                                         Job Location  \
# 0  Bangalore/Bengaluru, karnataka\n(WFH during Co...
# 1                                Bangalore/Bengaluru
# 2                 Bangalore/Bengaluru, Pune, Chennai
# 3                     Bangalore/Bengaluru, Ahmedabad
# 4  Bangalore/Bengaluru, Noida, Hyderabad/Secunder...
# 5                                Bangalore/Bengaluru
# 6                                Bangalore/Bengaluru
# 7                                Bangalore/Bengaluru
# 8               Bangalore/Bengaluru(Old Madras Road)
# 9                                Bangalore/Bengaluru
#
#                  Company Name
# 0                   Collabera
# 1             Thomson Reuters
# 2                       Capco
# 3  CURise Analytics Pvt. Ltd.
# 4                       Wipro
# 5                       Optum
# 6                       Optum
# 7             Thomson Reuters
# 8                    KrazyBee
# 9                Nuance India

# %% [markdown]
# # Q3. Answer:- A python program to scrape data for “Data Analyst” and have to scrape first 10 jobs data of the job-title, job-location filter (Delhi/NCR), company_name, salary filter (“3-6” lakhs)

# %%
driver3=webdriver.Chrome('chromedriver.exe')
driver3.get('https://www.naukri.com/')

# %%
driver3.maximize_window()

# %%
search_jobs3=driver3.find_element(By.CLASS_NAME,'suggestor-input').send_keys("Data Analyst")

# %%
search_button3= driver3.find_element("xpath",'/html/body/div[1]/div[2]/div[3]/div/div/div[6]').click()

# %%
loc_fil = driver3.find_element('xpath','/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[4]/div[2]/div[3]').click()

# %%
sal_check_box = driver3.find_element("xpath",'/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[5]/div[2]/div[2]/label/i').click()

# %%
title_tags3=driver3.find_elements("xpath",'//a[@class="title fw500 ellipsis"]')
job_title3=[]
for i in title_tags3:
    job_title3.append(i.text)

# %%
loc_tags3=driver3.find_elements("xpath",'//li[@class="fleft grey-text br2 placeHolderLi location"]')
job_loc3=[]
for i in loc_tags3:
    job_loc3.append(i.text)

# %%
loc_tags3=driver3.find_elements("xpath",'//li[@class="fleft grey-text br2 placeHolderLi location"]')
job_loc3=[]
for i in loc_tags3:
    job_loc3.append(i.text)

# %%
sal_3=driver3.find_elements("xpath",'//li[@class="fleft grey-text br2 placeHolderLi salary"]')
salary_3=[]
for i in sal_3:
    salary_3.append(i.text)

# %%
Data_Analyst_3=pd.DataFrame({'Job Title':job_title2,'Job Location':job_loc2,'Company Name':comp_title2, 'Location':job_loc3, 'Salary':salary_3})
Data_Analyst_3[0:10]
# Out:
#                                            Job Title  \
# 0                           Sr.Business Data Analyst
# 1                                    Sr Data Analyst
# 2                       Senior Data Analysis Analyst
# 3  Job opportunity For Data Analyst at Trellance ...
# 4                                       Data Analyst
# 5                             Associate Data Analyst
# 6                             Associate Data Analyst
# 7                                       Data Analyst
# 8                                Senior Data Analyst
# 9                             Financial Data Analyst
#
#                                         Job Location  \
# 0  Bangalore/Bengaluru, karnataka\n(WFH during Co...
# 1                                Bangalore/Bengaluru
# 2                 Bangalore/Bengaluru, Pune, Chennai
# 3                     Bangalore/Bengaluru, Ahmedabad
# 4  Bangalore/Bengaluru, Noida, Hyderabad/Secunder...
# 5                                Bangalore/Bengaluru
# 6                                Bangalore/Bengaluru
# 7                                Bangalore/Bengaluru
# 8               Bangalore/Bengaluru(Old Madras Road)
# 9                                Bangalore/Bengaluru
#
#                  Company Name  \
# 0                   Collabera
# 1             Thomson Reuters
# 2                       Capco
# 3  CURise Analytics Pvt. Ltd.
# 4                       Wipro
# 5                       Optum
# 6                       Optum
# 7             Thomson Reuters
# 8                    KrazyBee
# 9                Nuance India
#
#                                           Location                   Salary
# 0                                 Gurgaon/Gurugram            Not disclosed
# 1                                            Noida            Not disclosed
# 2                                            Noida            Not disclosed
# 3                                 Gurgaon/Gurugram            Not disclosed
# 4                                 Gurgaon/Gurugram            Not disclosed
# 5                    Delhi / NCR, Noida, Ghaziabad  4,00,000 - 7,00,000 PA.
# 6                                 Gurgaon/Gurugram            Not disclosed
# 7  Delhi / NCR, Noida, Faridabad, Gurgaon/Gurugram            Not disclosed
# 8                                      Delhi / NCR            Not disclosed
# 9                                            Noida            Not disclosed

# %% [markdown]
# # Q4. Answer:- Scrape data of first 100 sunglasses listings on flipkart.com with Brand, Product Description and Price

# %%
driver4=webdriver.Chrome('chromedriver.exe')
driver4.get('https://www.flipkart.com/')

# %%
driver4.maximize_window()

# %%
pop_close = driver4.find_element("xpath","/html/body/div[2]/div/div/button").click()

# %%
search_product=driver4.find_element(By.CLASS_NAME,'_3704LK').send_keys("Sunglasses")

# %%
search_button4= driver4.find_element(By.CLASS_NAME,'L0Z3Pu').click()

# %%
brand=driver4.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name=[]
for i in brand:
    brand_name.append(i.text)

# %%
product=driver4.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc=[]
for i in product:
    product_desc.append(i.text)

# %%
price=driver4.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price=[]
for i in price:
    product_price.append(i.text)

# %%
price_off=driver4.find_elements("xpath",'//div[@class="_3Ay6Sb"]')
Discount=[]
for i in price_off:
    Discount.append(i.text)

# %%
product_1=pd.DataFrame({'Brand Name':brand_name,'Product Description':product_desc,'Price':product_price,'Discount':Discount})
product_1[:40]
# Out:
#            Brand Name                                Product Description  \
# 0       VINCENT CHASE  by Lenskart Polarized, UV Protection Cat-eye S...
# 1           ROYAL SON   Polarized, UV Protection Aviator Sunglasses (57)
# 2            DAHAAZIL  UV Protection, Night Vision, Riding Glasses Wa...
# 3           New Specs   UV Protection Rectangular Sunglasses (Free Size)
# 4            Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# 5              SUNBEE  UV Protection, Polarized, Mirrored Retro Squar...
# 6           Elligator                UV Protection Round Sunglasses (54)
# 7      ROZZETTA CRAFT     UV Protection Spectacle Sunglasses (Free Size)
# 8              SUNBEE  UV Protection, Polarized Wayfarer Sunglasses (...
# 9              PIRASO              UV Protection Aviator Sunglasses (54)
# 10               SRPM             UV Protection Wayfarer Sunglasses (50)
# 11          ROYAL SON  Polarized, UV Protection Retro Square Sunglass...
# 12  SHAAH COLLECTIONS  UV Protection, Polarized, Mirrored Rectangular...
# 13           Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 14           Fastrack       UV Protection Aviator Sunglasses (Free Size)
# 15          ROYAL SON  Polarized, UV Protection Wayfarer, Retro Squar...
# 16             PIRASO              UV Protection Aviator Sunglasses (54)
# 17             PIRASO              UV Protection Aviator Sunglasses (58)
# 18         Lee Topper  Riding Glasses Wrap-around Sunglasses (Free Size)
# 19           elegante  Polarized, Riding Glasses, Night Vision Sports...
# 20     ROZZETTA CRAFT  Polarized, Riding Glasses Sports, Wrap-around ...
# 21         Lee Topper       UV Protection Cat-eye Sunglasses (Free Size)
# 22             PIRASO          UV Protection Rectangular Sunglasses (52)
# 23            Ray-Ban    Mirrored, UV Protection Aviator Sunglasses (58)
# 24             PIRASO             UV Protection Wayfarer Sunglasses (32)
# 25             PIRASO              UV Protection Aviator Sunglasses (54)
# 26              NuVew               UV Protection Sports Sunglasses (62)
# 27              povty  UV Protection Retro Square Sunglasses (Free Size)
# 28                 Mi           Polarized Aviator Sunglasses (Free Size)
# 29     ROZZETTA CRAFT   UV Protection Rectangular Sunglasses (Free Size)
# 30             PIRASO           UV Protection Over-sized Sunglasses (65)
# 31      VINCENT CHASE          UV Protection Rectangular Sunglasses (52)
# 32           Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...
# 33           Fastrack              UV Protection Aviator Sunglasses (58)
# 34  SHAAH COLLECTIONS         UV Protection Round Sunglasses (Free Size)
# 35            Ray-Ban                     Gradient Round Sunglasses (54)
# 36     ROZZETTA CRAFT  UV Protection, Gradient Retro Square Sunglasse...
# 37             Sewell  Mirrored, Night Vision, UV Protection, Riding ...
# 38               SRPM      Others Wayfarer, Retro Square Sunglasses (50)
# 39               hipe                  Mirrored Wayfarer Sunglasses (55)
#
#      Price Discount
# 0     ₹799  60% off
# 1     ₹759  62% off
# 2     ₹177  82% off
# 3     ₹264  89% off
# 4     ₹639  20% off
# 5     ₹259  80% off
# 6     ₹315  87% off
# 7     ₹379  81% off
# 8     ₹283  78% off
# 9     ₹224  85% off
# 10    ₹224  82% off
# 11    ₹616  69% off
# 12    ₹195  88% off
# 13    ₹799  20% off
# 14    ₹639  20% off
# 15    ₹664  66% off
# 16    ₹224  85% off
# 17    ₹359  86% off
# 18    ₹299  88% off
# 19    ₹499  78% off
# 20    ₹474  76% off
# 21    ₹229  82% off
# 22    ₹306  88% off
# 23  ₹3,909  30% off
# 24    ₹226  85% off
# 25    ₹246  84% off
# 26    ₹291  76% off
# 27    ₹319  68% off
# 28    ₹839  30% off
# 29    ₹303  79% off
# 30    ₹410  84% off
# 31    ₹649  67% off
# 32    ₹719  20% off
# 33  ₹1,039  20% off
# 34    ₹279  78% off
# 35  ₹9,799  10% off
# 36    ₹331  83% off
# 37    ₹265  82% off
# 38    ₹219  78% off
# 39    ₹233  76% off

# %%
page_2=driver4.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
brand=driver4.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name=[]
for i in brand:
    brand_name.append(i.text)

product=driver4.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc=[]
for i in product:
    product_desc.append(i.text)

price=driver4.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price=[]
for i in price:
    product_price.append(i.text)
    
price_off=driver4.find_elements("xpath",'//div[@class="_3Ay6Sb"]')
Discount=[]
for i in price_off:
    Discount.append(i.text)
    
product_2=pd.DataFrame({'Brand Name':brand_name[:40],'Product Description':product_desc[:40],'Price':product_price[:40],'Discount':Discount[:40]})

# %%
page_3=driver4.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
brand=driver4.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name=[]
for i in brand:
    brand_name.append(i.text)
    
product=driver4.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc=[]
for i in product:
    product_desc.append(i.text)
    
price=driver4.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price=[]
for i in price:
    product_price.append(i.text)
    
price_off=driver4.find_elements("xpath",'//div[@class="_3Ay6Sb"]')
Discount=[]
for i in price_off:
    Discount.append(i.text)
    
product_3=pd.DataFrame({'Brand Name':brand_name[:40],'Product Description':product_desc[:40],'Price':product_price[:40],'Discount':Discount[:40]})

# %%
page_4=driver4.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
brand=driver4.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name=[]
for i in brand:
    brand_name.append(i.text)
    
product=driver4.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc=[]
for i in product:
    product_desc.append(i.text)
    
price=driver4.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price=[]
for i in price:
    product_price.append(i.text)
    
price_off=driver4.find_elements("xpath",'//div[@class="_3Ay6Sb"]')
Discount=[]
for i in price_off:
    Discount.append(i.text)
    
product_4=pd.DataFrame({'Brand Name':brand_name[:40],'Product Description':product_desc[:40],'Price':product_price[:40],'Discount':Discount[:40]})

# %%
product=pd.concat([product_1,product_2,product_3], ignore_index=True)
product[:100]
# Out:
#         Brand Name                                Product Description Price  \
# 0    VINCENT CHASE  by Lenskart Polarized, UV Protection Cat-eye S...  ₹799
# 1        ROYAL SON   Polarized, UV Protection Aviator Sunglasses (57)  ₹759
# 2         DAHAAZIL  UV Protection, Night Vision, Riding Glasses Wa...  ₹177
# 3        New Specs   UV Protection Rectangular Sunglasses (Free Size)  ₹264
# 4         Fastrack   UV Protection Rectangular Sunglasses (Free Size)  ₹639
# ..             ...                                                ...   ...
# 95       ROYAL SON  Polarized, UV Protection Wayfarer, Retro Squar...  ₹664
# 96        Fastrack       UV Protection Aviator Sunglasses (Free Size)  ₹639
# 97          PIRASO              UV Protection Aviator Sunglasses (58)  ₹359
# 98  ROZZETTA CRAFT  Polarized, Riding Glasses Sports, Wrap-around ...  ₹474
# 99          GANSTA              UV Protection Aviator Sunglasses (57)  ₹314
#
#    Discount
# 0   60% off
# 1   62% off
# 2   82% off
# 3   89% off
# 4   20% off
# ..      ...
# 95  66% off
# 96  20% off
# 97  86% off
# 98  76% off
# 99  84% off
#
# [100 rows x 4 columns]

# %% [markdown]
# # Q5. Answer:- Scrape 100 reviews data from flipkart.com for iphone11 phone with Rating, Review summary and Full review

# %%
driver5=webdriver.Chrome('chromedriver.exe')
driver5.get('https://www.flipkart.com/')

# %%
driver5.maximize_window()

# %%
pop_close = driver5.find_element("xpath","/html/body/div[2]/div/div/button").click()

# %%
search_product2=driver5.find_element(By.CLASS_NAME,'_3704LK').send_keys("iphone11")

# %%
search_button5= driver5.find_element(By.CLASS_NAME,'L0Z3Pu').click()

# %%
driver5.get('https://www.flipkart.com/apple-iphone-11-black-128-gb/p/itm8244e8d955aba?pid=MOBFWQ6BKRYBP5X8&lid=LSTMOBFWQ6BKRYBP5X8X0KYUG&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=63c32ee7-45a3-47d9-ac06-21aeb6166759.MOBFWQ6BKRYBP5X8.SEARCH&ppt=hp&ppn=homepage&ssid=snwooq2qwg0000001657530664653&qH=d6db477051465f9a')

# %%
All_reviews=driver5.find_element("xpath",'//div[@class="_3UAT2v _16PBlm"]').click()

# %%
rating_tag1=driver5.find_elements("xpath",'//div[@class="_3LWZlK _1BLPMq"]')
rating1=[]
for i in rating_tag1:
    rating1.append(i.text)

review_sum1=driver5.find_elements("xpath",'//p[@class="_2-N8zT"]')
review1=[]
for i in review_sum1:
    review1.append(i.text)

review_full1=driver5.find_elements("xpath",'//div[@class="t-ZTKy"]')
full_review1=[]
for i in review_full1:
    full_review1.append(i.text.replace('\n',' , '))

iphone11_reviews1=pd.DataFrame({'Rating':rating1,'Review Summary':review1,'Full Review':full_review1})

# %%
next_2=driver5.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
rating_tag2=driver5.find_elements("xpath",'//div[@class="_3LWZlK _1BLPMq"]')
rating2=[]
for i in rating_tag2:
    rating2.append(i.text)

review_sum2=driver5.find_elements("xpath",'//p[@class="_2-N8zT"]')
review2=[]
for i in review_sum2:
    review2.append(i.text)

review_full2=driver5.find_elements("xpath",'//div[@class="t-ZTKy"]')
full_review2=[]
for i in review_full2:
    full_review2.append(i.text.replace('\n',' , '))
    
iphone11_reviews2=pd.DataFrame({'Rating':rating2,'Review Summary':review2,'Full Review':full_review2})

# %%
next_3=driver5.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
rating_tag3=driver5.find_elements("xpath",'//div[@class="_3LWZlK _1BLPMq"]')
rating3=[]
for i in rating_tag3:
    rating3.append(i.text)

review_sum3=driver5.find_elements("xpath",'//p[@class="_2-N8zT"]')
review3=[]
for i in review_sum3:
    review3.append(i.text)

review_full3=driver5.find_elements("xpath",'//div[@class="t-ZTKy"]')
full_review3=[]
for i in review_full3:
    full_review3.append(i.text.replace('\n',' , '))    
    
iphone11_reviews3=pd.DataFrame({'Rating':rating3,'Review Summary':review3,'Full Review':full_review3})

# %%
next_4=driver5.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
rating_tag4=driver5.find_elements("xpath",'//div[@class="_3LWZlK _1BLPMq"]')
rating4=[]
for i in rating_tag4:
    rating4.append(i.text)

review_sum4=driver5.find_elements("xpath",'//p[@class="_2-N8zT"]')
review4=[]
for i in review_sum4:
    review4.append(i.text)

review_full4=driver5.find_elements("xpath",'//div[@class="t-ZTKy"]')
full_review4=[]
for i in review_full4:
    full_review4.append(i.text.replace('\n',' , '))
        
iphone11_reviews4=pd.DataFrame({'Rating':rating4,'Review Summary':review4,'Full Review':full_review4})

# %%
next_5=driver5.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
rating_tag5=driver5.find_elements("xpath",'//div[@class="_3LWZlK _1BLPMq"]')
rating5=[]
for i in rating_tag5:
    rating5.append(i.text)

review_sum5=driver5.find_elements("xpath",'//p[@class="_2-N8zT"]')
review5=[]
for i in review_sum5:
    review5.append(i.text)

review_full5=driver5.find_elements("xpath",'//div[@class="t-ZTKy"]')
full_review5=[]
for i in review_full5:
    full_review5.append(i.text.replace('\n',' , '))
    
iphone11_reviews5=pd.DataFrame({'Rating':rating5,'Review Summary':review5,'Full Review':full_review5})

# %%
next_6=driver5.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
rating_tag6=driver5.find_elements("xpath",'//div[@class="_3LWZlK _1BLPMq"]')
rating6=[]
for i in rating_tag6:
    rating6.append(i.text)

review_sum6=driver5.find_elements("xpath",'//p[@class="_2-N8zT"]')
review6=[]

for i in review_sum6:
    review6.append(i.text)

review_full6=driver5.find_elements("xpath",'//div[@class="t-ZTKy"]')
full_review6=[]
for i in review_full6:
    full_review6.append(i.text.replace('\n',' , '))
    
iphone11_reviews6=pd.DataFrame({'Rating':rating6,'Review Summary':review6,'Full Review':full_review6})

# %%
next_7=driver5.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
rating_tag7=driver5.find_elements("xpath",'//div[@class="_3LWZlK _1BLPMq"]')
rating7=[]
for i in rating_tag7:
    rating7.append(i.text)

review_sum7=driver5.find_elements("xpath",'//p[@class="_2-N8zT"]')
review7=[]
for i in review_sum7:
    review7.append(i.text)

review_full7=driver5.find_elements("xpath",'//div[@class="t-ZTKy"]')
full_review7=[]
for i in review_full7:
    full_review7.append(i.text.replace('\n',' , '))
    
iphone11_reviews7=pd.DataFrame({'Rating':rating7,'Review Summary':review7,'Full Review':full_review7})

# %%
next_8=driver5.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
rating_tag8=driver5.find_elements("xpath",'//div[@class="_3LWZlK _1BLPMq"]')
rating8=[]
for i in rating_tag8:
    rating8.append(i.text)

review_sum8=driver5.find_elements("xpath",'//p[@class="_2-N8zT"]')
review8=[]
for i in review_sum8:
    review8.append(i.text)

review_full8=driver5.find_elements("xpath",'//div[@class="t-ZTKy"]')
full_review8=[]
for i in review_full8:
    full_review8.append(i.text.replace('\n',' , '))
    
iphone11_reviews8=pd.DataFrame({'Rating':rating8,'Review Summary':review8,'Full Review':full_review8})

# %%
next_9=driver5.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
rating_tag9=driver5.find_elements("xpath",'//div[@class="_3LWZlK _1BLPMq"]')
rating9=[]
for i in rating_tag9:
    rating9.append(i.text)

review_sum9=driver5.find_elements("xpath",'//p[@class="_2-N8zT"]')
review9=[]
for i in review_sum9:
    review9.append(i.text)

review_full9=driver5.find_elements("xpath",'//div[@class="t-ZTKy"]')
full_review9=[]
for i in review_full9:
    full_review9.append(i.text.replace('\n',' , '))
    
iphone11_reviews9=pd.DataFrame({'Rating':rating9,'Review Summary':review9,'Full Review':full_review9})

# %%
next_0=driver5.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
rating_tag0=driver5.find_elements("xpath",'//div[@class="_3LWZlK _1BLPMq"]')
rating0=[]
for i in rating_tag0:
    rating0.append(i.text)

review_sum0=driver5.find_elements("xpath",'//p[@class="_2-N8zT"]')
review0=[]
for i in review_sum0:
    review0.append(i.text)

review_full0=driver5.find_elements("xpath",'//div[@class="t-ZTKy"]')
full_review0=[]
for i in review_full0:
    full_review0.append(i.text.replace('\n',' , '))
    
iphone11_reviews0=pd.DataFrame({'Rating':rating0,'Review Summary':review0,'Full Review':full_review0})

# %%
iphone11_reviews=pd.concat([iphone11_reviews1,iphone11_reviews2,iphone11_reviews3,iphone11_reviews4,iphone11_reviews5,iphone11_reviews6,iphone11_reviews7,iphone11_reviews8,iphone11_reviews9,iphone11_reviews0], ignore_index=True)
iphone11_reviews[:100]
# Out:
#    Rating       Review Summary  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3       5   Highly recommended
# 4       5    Worth every penny
# ..    ...                  ...
# 95      5     Perfect product!
# 96      5             Terrific
# 97      5    Worth every penny
# 98      5            Wonderful
# 99      5       Simply awesome
#
#                                           Full Review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   What a camera .....just awesome ..you can feel...
# 4   Previously I was using one plus 3t it was a gr...
# ..                                                ...
# 95  Iphone is just awesome.. battery backup is ver...
# 96  Really worth of money. i just love it. It is t...
# 97  Best budget Iphone till date ❤️ go for it guys...
# 98  This is my first ever I phone. Before this I w...
# 99  Excellent camera, good performance, no lag. Th...
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q.6. Answer: Scrape data for first 100 sneakers you find when you visit flipkart.com

# %%
driver6=webdriver.Chrome('chromedriver.exe')
driver6.get('https://www.flipkart.com/')

# %%
driver6.maximize_window()

# %%
pop_close = driver6.find_element("xpath","/html/body/div[2]/div/div/button").click()

# %%
search_product6=driver6.find_element(By.CLASS_NAME,'_3704LK').send_keys("sneakers")

# %%
search_button6= driver6.find_element(By.CLASS_NAME,'L0Z3Pu').click()

# %%
brand6=driver6.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name6=[]
for i in brand6:
    brand_name6.append(i.text)
    
product6=driver6.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc6=[]
for i in product6:
    product_desc6.append(i.text)
    
price6=driver6.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price6=[]
for i in price6:
    product_price6.append(i.text)
    
price_off6=driver6.find_elements("xpath",'//div[@class="_3Ay6Sb"]')
Discount6=[]
for i in price_off6:
    Discount6.append(i.text)

# %%
print(len(product_desc6),len(product_price6),len(Discount6),len(brand_name6))
# Out:
# 33 40 40 40

# %%
sneaker1=pd.DataFrame({'Brand Name':brand_name6[:30],'Product Description':product_desc6[:30], 'Product Price':product_price6[:30],'Discount':Discount6[:30]})

# %%
page_2=driver6.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
brand6=driver6.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name6=[]
for i in brand6:
    brand_name6.append(i.text)
    
product6=driver6.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc6=[]
for i in product6:
    product_desc6.append(i.text)
    
price6=driver6.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price6=[]
for i in price6:
    product_price6.append(i.text)
    
price_off6=driver6.find_elements("xpath",'//div[@class="_3Ay6Sb"]')
Discount6=[]
for i in price_off6:
    Discount6.append(i.text)
    
sneaker2=pd.DataFrame({'Brand Name':brand_name6[:30],'Product Description':product_desc6[:30], 'Product Price':product_price6[:30],'Discount':Discount6[:30]})

# %%
page_3=driver6.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
brand6=driver6.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name6=[]
for i in brand6:
    brand_name6.append(i.text)
    
product6=driver6.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc6=[]
for i in product6:
    product_desc6.append(i.text)
    
price6=driver6.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price6=[]
for i in price6:
    product_price6.append(i.text)
    
price_off6=driver6.find_elements("xpath",'//div[@class="_3Ay6Sb"]')
Discount6=[]
for i in price_off6:
    Discount6.append(i.text)
    
sneaker3=pd.DataFrame({'Brand Name':brand_name6[:30],'Product Description':product_desc6[:30], 'Product Price':product_price6[:30],'Discount':Discount6[:30]})

# %%
page_4=driver6.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
brand6=driver6.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name6=[]
for i in brand6:
    brand_name6.append(i.text)
    
product6=driver6.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc6=[]
for i in product6:
    product_desc6.append(i.text)
    
price6=driver6.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price6=[]
for i in price6:
    product_price6.append(i.text)
    
price_off6=driver6.find_elements("xpath",'//div[@class="_3Ay6Sb"]')
Discount6=[]
for i in price_off6:
    Discount6.append(i.text)
    
sneaker4=pd.DataFrame({'Brand Name':brand_name6[:10],'Product Description':product_desc6[:10], 'Product Price':product_price6[:10],'Discount':Discount6[:10]})

# %%
sneaker=pd.concat([sneaker1,sneaker2,sneaker3,sneaker4], ignore_index=True)
sneaker[:100]
# Out:
#       Brand Name                                Product Description  \
# 0    ZF - ALFIYA                                   Sneakers For Men
# 1         FEWEYU           Fashionable casual sneaker shoes Sneaker
# 2       WOODLAND                                   Sneakers For Men
# 3         BRUTON           Modern Trendy Sneakers Shoes Sneakers Fo
# 4         BRUTON           Modern Trendy Sneakers Shoes Sneakers Fo
# ..           ...                                                ...
# 95          PUMA                    ST Activate V2 Sneakers For Men
# 96    D-SNEAKERZ  Casual , Partywear Sneakers Shoes For Men's An...
# 97        BRUTON  Combo Pack Of 4 Casual Shoes Loafer Shoes Snea...
# 98  Robbie jones  Casual Sneakers Canvas Shoes For Men Sneakers ...
# 99        BRUTON             Lattest Sneakers Shoe Sneakers For Men
#
#    Product Price Discount
# 0           ₹449  55% off
# 1           ₹499  75% off
# 2         ₹2,096  30% off
# 3           ₹284  78% off
# 4           ₹299  76% off
# ..           ...      ...
# 95        ₹1,749  50% off
# 96          ₹299  54% off
# 97          ₹499  85% off
# 98          ₹499  50% off
# 99          ₹269  79% off
#
# [100 rows x 4 columns]

# %% [markdown]
# # Q.7.Answer: Scrape First 100 shoes data from MYNTRA.COM

# %%
driver7=webdriver.Chrome('chromedriver.exe')

# %%
driver7.maximize_window()

# %%
driver7.get('https://www.myntra.com')

# %%
driver7.get('https://www.myntra.com/shoes')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18056/1289648309.py in <module>
# ----> 1 driver7.get('https://www.myntra.com/shoes')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     445         Loads a web page in the current browser session.
#     446         """
# --> 447         self.execute(Command.GET, {'url': url})
#     448
#     449     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     433         response = self.command_executor.execute(driver_command, params)
#     434         if response:
# --> 435             self.error_handler.check_response(response)
#     436             response['value'] = self._unwrap_value(
#     437                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: unknown error: cannot determine loading status
# from unknown error: unexpected command response
#   (Session info: chrome=103.0.5060.114)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01176463+2188387]
# 	Ordinal0 [0x0110E461+1762401]
# 	Ordinal0 [0x01023D78+802168]
# 	Ordinal0 [0x01017210+750096]
# 	Ordinal0 [0x0101675A+747354]
# 	Ordinal0 [0x01015D3F+744767]
# 	Ordinal0 [0x01014C28+740392]
# 	Ordinal0 [0x01015228+741928]
# 	Ordinal0 [0x0101EF2F+782127]
# 	Ordinal0 [0x01029FBB+827323]
# 	Ordinal0 [0x0102D310+840464]
# 	Ordinal0 [0x010154F6+742646]
# 	Ordinal0 [0x01029BF3+826355]
# 	Ordinal0 [0x0107CF6D+1167213]
# 	Ordinal0 [0x0106C5F6+1099254]
# 	Ordinal0 [0x01046BE0+945120]
# 	Ordinal0 [0x01047AD6+948950]
# 	GetHandleVerifier [0x014171F2+2712546]
# 	GetHandleVerifier [0x0140886D+2652765]
# 	GetHandleVerifier [0x0120002A+520730]
# 	GetHandleVerifier [0x011FEE06+516086]
# 	Ordinal0 [0x0111468B+1787531]
# 	Ordinal0 [0x01118E88+1805960]
# 	Ordinal0 [0x01118F75+1806197]
# 	Ordinal0 [0x01121DF1+1842673]
# 	BaseThreadInitThunk [0x760B6739+25]
# 	RtlGetFullPathName_UEx [0x779D8FEF+1215]
# 	RtlGetFullPathName_UEx [0x779D8FBD+1165]

# %% [markdown]
# # Q.8.Answer: Scrape First 100 shoes data from Amazon.com

# %%
driver7=webdriver.Chrome('chromedriver.exe')
driver7.get('https://www.amazon.in/')

# %%
driver7.maximize_window()

# %%
search_product7=driver7.find_element(By.ID,"twotabsearchtextbox").send_keys("Laptop")

# %%
search_product7=driver7.find_element(By.ID,"nav-search-submit-button").click()

# %%
cpu = driver7.find_element('xpath','/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[4]/li[12]/span/a/div/label/i').click()

# %%
title7=driver7.find_elements("xpath",'//span[@class="a-size-medium a-color-base a-text-normal"]')
title=[]
for i in title7:
    title.append(i.text)
    

Ratings7=driver7.find_elements("xpath",'//div[@class="a-row a-size-small"]')
rating7=[]
for i in Ratings7:
    rating7.append(i.text)
    
price7=driver7.find_elements("xpath",'//span[@class="a-price-whole"]')
price_7=[]
for i in price7:
    price_7.append(i.text)

# %%
laptop=pd.DataFrame({'Laptop Name':title[:10],'Rating':rating7[:10], 'Price':price_7[:10]})
laptop[:10]
# Out:
#                                          Laptop Name Rating     Price
# 0  Lenovo IdeaPad Slim 5 Pro Intel Core i7 11th G...      9    75,990
# 1  Fujitsu UH-X 11th Gen Intel Core i7 13.3” FHD ...     60    84,990
# 2  Hp Pavilion X360 11Th Gen Intel Core I7 14 Inc...     13    83,603
# 3  Hp Pavilion 15 12Th Gen Intel Core I7 16Gb Sdr...      5    87,990
# 4  HP Envy 11th Gen Intel Evo Core i7 14 inch(35....      7    99,699
# 5  ASUS TUF Dash F15 (2022), 15.6-inch (39.62 cms...      1  1,64,980
# 6  ASUS TUF Gaming F15 (2022), 15.6-inch (39.62 c...     17  1,12,990
# 7  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...      9    99,442
# 8  Lenovo ThinkBook 15 Intel 11th Gen Core i7 15....     49    86,990
# 9  ASUS TUF Dash F15 (2022), 15.6-inch (39.62 cms...    161    86,990

# %% [markdown]
# # Q.9.Answer: A python program to scrape data for first 10 job results for Data Scientist Designation in Noida location with company name, No. of days ago when job was posted, Rating of the company

# %%
driver9=webdriver.Chrome('chromedriver.exe')
driver9.get('https://www.ambitionbox.com/')

# %%
driver9.maximize_window()

# %%
jobs=driver9.find_element("xpath",'/html/body/div[1]/nav/nav/a[6]').click()

# %%
search_jobs=driver9.find_element("xpath",'//INPUT[@class="input tt-input"]').send_keys("Data Scientist")

# %%
search_button9= driver9.find_element(By.CLASS_NAME,"ctas-btn-medium").click()

# %%
location=driver9.find_element("xpath",'/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[1]/p').click()

# %%
search_location=driver9.find_element("xpath",'/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[2]/input').send_keys("Noida")

# %%
job_location=driver9.find_element("xpath",'/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[3]/div[1]/div[1]/div/label').click()

# %%
job_tags=driver9.find_elements("xpath",'//a[@class="title noclick"]')
jobs_title=[]
for i in job_tags:
    jobs_title.append(i.text)
    
job_comp1=driver9.find_elements("xpath",'//p[@class="company body-medium"]')
jobs_comp=[]
for i in job_comp1:
    jobs_comp.append(i.text)
    
Job_post=driver9.find_elements("xpath"," //div[@class='other-info']/span[1]" )
job_posted=[]
for i in Job_post:
    job_posted.append(i.text)
    
comp_rat1=driver9.find_elements(By.CLASS_NAME,"body-small")
comp_ratg=[]
for i in comp_rat1:
    comp_ratg.append(i.text)

# %%
Ambition=pd.DataFrame({'Company Name':jobs_comp,'Job Posted':job_posted,'Rating':comp_ratg})
Ambition[:10]
# Out:
#                                      Company Name Job Posted Rating
# 0  Optum Global Solutions (India) Private Limited     8d ago    4.1
# 1                   GENPACT India Private Limited    15d ago    4.0
# 2                         Dew Solutions Pvt. Ltd.     6d ago    4.3
# 3                             InfoEdge India Ltd.    13d ago    3.9
# 4                         Info Edge India Limited    14d ago    3.9
# 5                         Info Edge India Limited    14d ago    3.9
# 6                                   Latent bridge    14d ago    4.5
# 7                                       Careerera     1d ago    3.8
# 8                            Careernet Consulting    28d ago    3.9
# 9                     Acidaes Solutions Pvt. Ltd.    14d ago    3.8

# %% [markdown]
# # Q.10.Answer: A python program to scrape the salary data for Data Scientist designation with Company name, Number of salaries, Average salary, Minsalary, Max Salary

# %%
driver0=webdriver.Chrome('chromedriver.exe')
driver0.get('https://www.ambitionbox.com/')

# %%
driver0.maximize_window()

# %%
salaries=driver0.find_element("xpath",'/html/body/div[1]/nav/nav/a[4]').click()

# %%
search_job2=driver0.find_element("xpath","//input[@class='tt-input']").send_keys("Data Scientist")

# %%
search_button0 = driver0.find_element(By.CLASS_NAME,'tt_text')

# %%
company_tag = driver0.find_elements("xpath","//div[@class='company-info']/a")
Company_name = []
for i in company_tag : 
    Company_name.append(i.text.split('\n')[0])
    
exp_tag = driver0.find_elements("xpath","//div[@class='sbold-list-header']")
Experience = []
for i in exp_tag : 
    Experience.append(i.text.split()[0]+" "+i.text.split()[1])   

salary_records = driver0.find_elements("xpath","//span[@class='datapoints']")
Total_Salary_Records = []
for i in salary_records: 
    Total_Salary_Records.append(i.text)

    
avg_salary = driver0.find_elements("xpath","//p[@class='averageCtc']")
Average_Salary = []
for i in avg_salary : 
    Average_Salary.append(i.text)
    
min_salary = driver0.find_elements("xpath","//div[@class='salary-values']")
Minimum_Salary = []
for i in min_salary : 
    Minimum_Salary.append(i.text.split("\n")[0])   
    
max_salary = driver0.find_elements("xpath","//div[@class='salary-values']")
Maximum_Salary = []
for i in max_salary : 
    Maximum_Salary.append(i.text.split("\n")[1])

# %%
data_ambition=pd.DataFrame({'Company Name':Company_name, 'Experience': Experience,'Total Salary Record':Total_Salary_Records, 'Average Salary': Average_Salary, 'Minimum Salary':Minimum_Salary, 'Maximum Salary':Maximum_Salary})
data_ambition[:10]
# Out:
#                             Company Name Experience      Total Salary Record  \
# 0                                 Google    1-3 yrs   (based on 35 salaries)
# 1                  Microsoft Corporation    1-4 yrs  (based on 274 salaries)
# 2                          Goldman Sachs      2 yrs   (based on 18 salaries)
# 3                                 Tekion    2-4 yrs   (based on 35 salaries)
# 4                                 Amazon    1-4 yrs  (based on 122 salaries)
# 5  Servicenow Software Development India    2-4 yrs   (based on 60 salaries)
# 6                               Flipkart    1-4 yrs   (based on 64 salaries)
# 7                                Walmart    1-4 yrs   (based on 87 salaries)
# 8                                 PayPal    1-2 yrs   (based on 29 salaries)
# 9                                 Myntra       1 yr   (based on 10 salaries)
#
#   Average Salary Minimum Salary Maximum Salary
# 0        ₹ 31.3L        ₹ 11.0L        ₹ 65.0L
# 1        ₹ 24.0L        ₹ 13.0L        ₹ 50.0L
# 2        ₹ 23.0L        ₹ 12.0L        ₹ 34.0L
# 3        ₹ 21.2L        ₹ 12.0L        ₹ 33.0L
# 4        ₹ 21.0L         ₹ 8.0L        ₹ 45.0L
# 5        ₹ 20.5L        ₹ 13.0L        ₹ 28.0L
# 6        ₹ 20.4L         ₹ 7.5L        ₹ 31.0L
# 7        ₹ 20.0L        ₹ 11.4L        ₹ 32.5L
# 8        ₹ 19.9L        ₹ 11.0L        ₹ 31.0L
# 9        ₹ 19.5L        ₹ 14.0L        ₹ 27.0L

# %% [markdown]
# # NOTE: Q.7 is to Scrap Data from Myntra.com but this site is not allowing to scrap data, so not able to do that
